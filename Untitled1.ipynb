# %% [markdown]
# <a href="https://colab.research.google.com/github/joannathom/Knowledge-Check-2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ufo_sighting_data.csv.zip')
df.head()
# Out:
# <ipython-input-173-8613cba83b24>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ufo_sighting_data.csv.zip')
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# ...

# %%
print(df.shape)
# Out:
# (80332, 11)

# %%
df.columns
# Out:
# Index(['Date_time', 'city', 'state/province', 'country', 'UFO_shape',
#        'length_of_encounter_seconds', 'described_duration_of_encounter',
#        'description', 'date_documented', 'latitude', 'longitude'],
#       dtype='object')

# %%
fixed_columns = {
    'Date_time':'DATE_TIME','city':'CITY', 'state/province': 'STATE/PROVINCE','country':'COUNTRY',
    'UFO_shape':'UFO_SHAPE',
    'length_of_encounter_seconds':'ENCOUNTER/SECONDS',
    'described_duration_of_encounter':'ENCOUNTER/DURATION DESCRIPTION',
    'description':'DESCRIPTION', 'date_documented' : 'DATE_DOCUMENTED','latitude': 'LATITUDE',
    'longitude': 'LONGITUDE'
}

df.rename(columns=fixed_columns,inplace=True)
df.columns
# Out:
# Index(['DATE_TIME', 'CITY', 'STATE/PROVINCE', 'COUNTRY', 'UFO_SHAPE',
#        'ENCOUNTER/SECONDS', 'ENCOUNTER/DURATION DESCRIPTION', 'DESCRIPTION',
#        'DATE_DOCUMENTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head()
# Out:
#           DATE_TIME                  CITY STATE/PROVINCE COUNTRY UFO_SHAPE  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   ENCOUNTER/SECONDS ENCOUNTER/DURATION DESCRIPTION  \
# 0              2700                     45 minutes
# 1              7200                        1-2 hrs
# 2                20                     20 seconds
# 3                20                       1/2 hour
# 4               900                     15 minutes
#
#                                          DESCRIPTION DATE_DOCUMENTED  \
# 0  This event took place in early fall around 194...       4/27/2004
# ...

# %%
df.CITY.unique()
# Out:
# array(['san marcos', 'lackland afb', 'chester (uk/england)', ...,
#        'calmar (canada)', 'aleksandrow (poland)', 'hamstead (hollyridge)'],
#       dtype=object)

# %%
df[df.CITY.str.contains('null')].head()
# Out:
#               DATE_TIME                          CITY STATE/PROVINCE COUNTRY  \
# 1972   10/15/1999 03:00  conconully (conconully lake)             wa      us
# 48252   6/13/2004 12:28                    conconully             wa      us
#
#       UFO_SHAPE ENCOUNTER/SECONDS ENCOUNTER/DURATION DESCRIPTION  \
# 1972      light              1800                  maybe 30 min.
# 48252      disk                 5                      5 seconds
#
#                                              DESCRIPTION DATE_DOCUMENTED  \
# 1972   A very bright light shined through the window ...       9/19/2002
# 48252  Saucer-shaped object appeared to move across s...       6/18/2004
#
#       LATITUDE   LONGITUDE
# 1972   48.5575 -119.748611
# 48252  48.5575 -119.748611

# %%
df.CITY.replace({'null':''}, regex=True,inplace=True)

# %%
df[df.CITY.str.contains('null')].head()
# Out:
# Empty DataFrame
# Columns: [DATE_TIME, CITY, STATE/PROVINCE, COUNTRY, UFO_SHAPE, ENCOUNTER/SECONDS, ENCOUNTER/DURATION DESCRIPTION, DESCRIPTION, DATE_DOCUMENTED, LATITUDE, LONGITUDE]
# Index: []

# %%
df.dropna()
# Out:
#               DATE_TIME        CITY STATE/PROVINCE COUNTRY UFO_SHAPE  \
# 0      10/10/1949 20:30  san marcos             tx      us  cylinder
# 3      10/10/1956 21:00        edna             tx      us    circle
# 4      10/10/1960 20:00     kaneohe             hi      us     light
# 5      10/10/1961 19:00     bristol             tn      us    sphere
# 7      10/10/1965 23:45     norwalk             ct      us      disk
# ...                 ...         ...            ...     ...       ...
# 80327    9/9/2013 21:15   nashville             tn      us     light
# 80328    9/9/2013 22:00       boise             id      us    circle
# 80329    9/9/2013 22:00        napa             ca      us     other
# 80330    9/9/2013 22:20      vienna             va      us    circle
# 80331    9/9/2013 23:00      edmond             ok      us     cigar
#
#       ENCOUNTER/SECONDS ENCOUNTER/DURATION DESCRIPTION  \
# 0                  2700                     45 minutes
# ...
